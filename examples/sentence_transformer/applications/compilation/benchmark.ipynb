# %% [markdown]
# Ideally run on a GPU w/ bfloat16 on it, e.g., an L4.

# %%
# !nvidia-smi

# %%
# If this example is merged upstream, point REPO_URL at
# https://github.com/huggingface/sentence-transformers.git and BRANCH at "main".
REPO_URL = "https://github.com/kddubey/sentence-transformers.git"
BRANCH = "kddubey/examples/compilation"
EXAMPLE_DIR = "sentence-transformers/examples/sentence_transformer/applications/compilation"

# %%
# !pip install -q uv
![ -d sentence-transformers ] || git clone -q -b $BRANCH $REPO_URL

# %%
# !cd sentence-transformers && uv run examples/sentence_transformer/applications/compilation/benchmark.py
